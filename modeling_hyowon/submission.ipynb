# %%
# Import libraries

import numpy as np
import pandas as pd
import scipy as sp
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.api as sm
from sklearn.datasets import make_regression
from sklearn.linear_model import LinearRegression
from patsy import dmatrix
from sklearn import linear_model
from sklearn.metrics import r2_score
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import KFold
# Pretty display for notebooks

# %matplotlib inline


# Allows the use of display() for DataFrames
from IPython.display import display 

# Ignore the warnings
import warnings
warnings.filterwarnings('ignore')

# Load the dataset
# train = pd.read_csv("../asset/train.csv")
# test = pd.read_csv("../asset/test.csv")
weather = pd.read_csv("./asset/weather+holyday_201807041434.csv")
# key = pd.read_csv("../asset/key.csv")
submission_example = pd.read_csv("../asset/sampleSubmission.csv")

# Success - Display the first record


# import pickle
import awesome_functions as cf

# 원본을 유지하기 위해서 카피
# df_train = train.copy()
df_weather = weather.copy()
# df_key = key.copy()
# df_test = test.copy()
df_submission = submission_example.copy()

# %%
df_submission.head()
# Out:
#                id  units
# 0  2_1_2013-04-01      0
# 1  2_2_2013-04-01      0
# 2  2_3_2013-04-01      0
# 3  2_4_2013-04-01      0
# 4  2_5_2013-04-01      0

# %%
df_submission.dtypes
# Out:
# id       object
# units     int64
# dtype: object

# %%
def store(a):
    return a.split("_")[0]

def item(a):
    return a.split("_")[1]

def date(a):
    return a.split("_")[2]

# %%
df_submission["store_nbr"] = df_submission["id"].apply(store)

# %%
df_submission["item_nbr"] = df_submission["id"].apply(item)

# %%
df_submission["date"] = df_submission["id"].apply(date)

# %%
df_submission.tail()
# Out:
#                        id  units store_nbr item_nbr        date
# 526912  45_107_2014-10-26      0        45      107  2014-10-26
# 526913  45_108_2014-10-26      0        45      108  2014-10-26
# 526914  45_109_2014-10-26      0        45      109  2014-10-26
# 526915  45_110_2014-10-26      0        45      110  2014-10-26
# 526916  45_111_2014-10-26      0        45      111  2014-10-26

# %%
df_submission = df_submission.drop(columns=["id"])

# %%
df_submission.head()
# Out:
#    units store_nbr item_nbr        date
# 0      0         2        1  2013-04-01
# 1      0         2        2  2013-04-01
# 2      0         2        3  2013-04-01
# 3      0         2        4  2013-04-01
# 4      0         2        5  2013-04-01

# %%
df_weather.columns
# Out:
# Index(['station_nbr', 'date', 'tmax', 'tmin', 'tavg', 'depart', 'dewpoint',
#        'wetbulb', 'heat', 'cool', 'sunrise', 'sunset', 'codesum', 'snowfall',
#        'preciptotal', 'stnpressure', 'sealevel', 'resultspeed', 'resultdir',
#        'avgspeed', 'year', 'month', 'day', 'weekday', 'holiday'],
#       dtype='object')

# %%
df = df_weather

# %%
# date 관련 column 만들어주기 
# weekday, friday, weekend 값 변수로 넣기
import datetime
def isweekend(dt) : 
    temp = str(dt)
    day, month, year = (int(x) for x in temp.split('-'))  
    ans = datetime.date(day, month, year)
    p = datetime.date.weekday(ans)
    if p <= 4 : 
        return 'weekday'
    elif (p == 5) :
        return 'Friday'
    else : 
        return 'weekend'
df['is_weekend'] = df['date'].apply(isweekend)

# holiday 추가해주기 
import re 
with open('./asset/holidays.txt') as file:  
    data = file.readlines()
    holidays = []
    BF = []
    months = ["", "Jan", "Feb", "Mar", "Apr", "May", "Jun", "Jul", "Aug", "Sep", "Oct", "Nov", "Dec"]
    for holiday in data : 
        if re.findall("BlackFriday", holiday) != [] :
            BF.append(holiday.split(" ")[:3])
        elif re.findall('Thanksgiving',holiday) != []:
            BF.append(holiday.split(" ")[:3])
        else :
            holidays.append(holiday.split(" ")[:3])
    for i in range(len(holidays)): 
        month_idx = months.index(holidays[i][1])
        if month_idx < 10:
            holidays[i][1] = "0" + str(month_idx)
        else:
            holidays[i][1] = str(month_idx)
    for z in range(len(holidays)) : 
        if len(holidays[z][2]) == 1 : 
            holidays[z][2] = '0' + holidays[z][2]
    for z in range(len(BF)) :
        BF[z][1] = '11'
		
		
# holiday 구분하기 
def isholiday(dt): 
    temp = str(dt)
    if temp.split("-") in BF :
        return "black friday"
    elif temp.split("-") in holidays :
        return "holiday"
    else :
        return "regular day"

df['is_holiday'] = df['date'].apply(isholiday)

# %%
df.head()
# Out:
#    station_nbr        date  tmax  tmin  tavg  depart  dewpoint  wetbulb  heat  \
# 0            1  2012-01-01    52    31    41      11        36       40    24
# 1            1  2012-01-02    50    31    40      10        26       35    25
# 2            1  2012-01-03    32    11    21      -8         4       18    44
# 3            1  2012-01-04    28     9    18     -11        -1       14    47
# 4            1  2012-01-05    38    25    31       1        13       25    34
#
#    cool     ...      resultspeed resultdir avgspeed  year  month  day  \
# 0     0     ...              3.6      20.0      4.6  2012      1    1
# 1     0     ...              9.8      24.0     10.3  2012      1    2
# 2     0     ...             10.8      31.0     11.6  2012      1    3
# 3     0     ...              6.3      27.0      8.3  2012      1    4
# 4     0     ...              6.9      25.0      7.8  2012      1    5
#
#    weekday      holiday  is_weekend   is_holiday
# 0        6      holiday     weekend      holiday
# 1        0  regular day     weekday      holiday
# 2        1  regular day     weekday  regular day
# 3        2  regular day     weekday  regular day
# 4        3  regular day     weekday  regular day
#
# [5 rows x 27 columns]

# %%
key = pd.read_csv("./asset/key.csv")

# %%
df_key = key.copy()

# %%
df_key
# Out:
#     store_nbr  station_nbr
# 0           1            1
# 1           2           14
# 2           3            7
# 3           4            9
# 4           5           12
# 5           6           14
# 6           7            6
# 7           8            4
# 8           9           17
# 9          10           12
# 10         11           10
# 11         12           11
# 12         13            6
# 13         14           16
# 14         15           13
# 15         16            2
# 16         17           20
# 17         18           17
# 18         19           15
# 19         20            7
# 20         21            3
# 21         22           10
# 22         23           17
# 23         24            9
# 24         25           13
# 25         26           17
# 26         27           10
# 27         28            7
# 28         29            3
# 29         30           19
# 30         31           17
# 31         32           13
# 32         33            3
# 33         34           17
# 34         35            5
# 35         36           18
# 36         37           13
# 37         38           14
# 38         39            8
# 39         40           13
# 40         41           12
# 41         42           14
# 42         43           11
# 43         44           12
# 44         45           16

# %%
df_key.dtypes
# Out:
# store_nbr      int64
# station_nbr    int64
# dtype: object

# %%
df_submission["store_nbr"] = df_submission["store_nbr"].astype(int)

# %%
df_submission.dtypes
# Out:
# units         int64
# store_nbr     int32
# item_nbr     object
# date         object
# dtype: object

# %%
df_submission = df_submission.merge(df_key, on="store_nbr")

# %%
df_weather
# Out:
#        station_nbr        date  tmax  tmin  tavg  depart  dewpoint  wetbulb  \
# 0                1  2012-01-01    52    31    41      11        36       40
# 1                1  2012-01-02    50    31    40      10        26       35
# 2                1  2012-01-03    32    11    21      -8         4       18
# 3                1  2012-01-04    28     9    18     -11        -1       14
# 4                1  2012-01-05    38    25    31       1        13       25
# 5                1  2012-01-06    46    25    35       5        21       29
# 6                1  2012-01-07    57    28    42      12        28       36
# 7                1  2012-01-08    45    27    36       6        22       32
# 8                1  2012-01-09    39    23    31       1        12       25
# 9                1  2012-01-10    47    29    38       8        24       32
# 10               1  2012-01-11    39    24    31       1        21       29
# 11               1  2012-01-12    40    31    35       5        31       34
# 12               1  2012-01-13    50    30    40      10        27       32
# 13               1  2012-01-14    35    14    24      -5        12       23
# 14               1  2012-01-15    16     4    10     -19        -5        7
# 15               1  2012-01-16    32     8    20      -9         3       17
# 16               1  2012-01-17    46    32    39       9        34       37
# 17               1  2012-01-18    50    19    34       4        15       29
# 18               1  2012-01-19    31    13    22      -7        11       20
# 19               1  2012-01-20    31    19    25      -4        12       23
# 20               1  2012-01-21    20    13    16     -13         9       16
# 21               1  2012-01-22    28     7    17     -12        12       18
# 22               1  2012-01-23    48    27    37       7        30       34
# 23               1  2012-01-24    55    41    48      18        39       44
# 24               1  2012-01-25    42    35    38       8        23       32
# 25               1  2012-01-26    43    32    37       7        23       31
# 26               1  2012-01-27    45    34    39       9        36       38
# 27               1  2012-01-28    48    32    40      10        27       35
# 28               1  2012-01-29    43    31    37       7        15       30
# 29               1  2012-01-30    39    25    32       2        15       27
# ...            ...         ...   ...   ...   ...     ...       ...      ...
# 19635           20  2014-10-02    95    65    80      11        67       71
# 19636           20  2014-10-03    83    58    70       1        49       59
# 19637           20  2014-10-04    80    47    63      -5        36       51
# 19638           20  2014-10-05    86    61    73       4        56       63
# 19639           20  2014-10-06    86    65    75       6        62       67
# 19640           20  2014-10-07    97    70    83      14        65       71
# 19641           20  2014-10-08    91    74    82      13        68       72
# 19642           20  2014-10-09    93    76    84      15        68       73
# 19643           20  2014-10-10    94    65    79      10        65       71
# 19644           20  2014-10-11    66    53    59      -9        54       57
# 19645           20  2014-10-12    76    51    63      -5        58       61
# 19646           20  2014-10-13    77    60    68       0        52       57
# 19647           20  2014-10-14    79    55    67      -1        41       53
# 19648           20  2014-10-15    85    48    66      -2        44       55
# 19649           20  2014-10-16    89    59    74       5        45       58
# 19650           20  2014-10-17    89    60    74       5        53       62
# 19651           20  2014-10-18    84    65    74       5        55       62
# 19652           20  2014-10-19    78    57    67      -1        54       59
# 19653           20  2014-10-20    83    57    70       1        57       62
# 19654           20  2014-10-21    83    55    69       0        56       61
# 19655           20  2014-10-22    81    60    70       1        58       63
# 19656           20  2014-10-23    80    63    71       2        55       61
# 19657           20  2014-10-24    85    60    72       3        57       63
# 19658           20  2014-10-25    90    64    77       8        59       65
# 19659           20  2014-10-26    89    68    78       9        56       64
# 19660           20  2014-10-27    85    66    75       6        59       65
# 19661           20  2014-10-28    80    68    74       5        60       65
# 19662           20  2014-10-29    78    55    66      -2        47       56
# 19663           20  2014-10-30    80    52    66      -2        50       57
# 19664           20  2014-10-31    68    50    59      -9        39       50
#
#        heat  cool     ...      resultspeed resultdir avgspeed  year  month  \
# 0        24     0     ...              3.6      20.0      4.6  2012      1
# 1        25     0     ...              9.8      24.0     10.3  2012      1
# 2        44     0     ...             10.8      31.0     11.6  2012      1
# 3        47     0     ...              6.3      27.0      8.3  2012      1
# 4        34     0     ...              6.9      25.0      7.8  2012      1
# 5        30     0     ...              0.3       1.0      2.4  2012      1
# 6        23     0     ...              3.0      26.0      3.6  2012      1
# 7        29     0     ...              5.1      30.0      6.6  2012      1
# 8        34     0     ...              2.3      23.0      4.0  2012      1
# 9        27     0     ...              5.4      25.0      6.5  2012      1
# 10       34     0     ...              3.4       7.0      4.2  2012      1
# 11       30     0     ...             10.7       5.0     12.3  2012      1
# 12       25     0     ...              8.7      24.0     12.7  2012      1
# 13       41     0     ...             11.1      28.0     12.5  2012      1
# 14       55     0     ...             11.2      31.0     11.6  2012      1
# 15       45     0     ...              5.1      23.0      7.1  2012      1
# 16       26     0     ...              4.9      21.0      5.9  2012      1
# 17       31     0     ...             13.7      29.0     15.9  2012      1
# 18       43     0     ...              1.4       4.0      2.9  2012      1
# 19       40     0     ...              6.0      29.0      6.7  2012      1
# 20       49     0     ...              5.9       1.0      6.0  2012      1
# 21       48     0     ...              3.4       4.0      3.7  2012      1
# 22       28     0     ...              0.8       7.0      2.2  2012      1
# 23       17     0     ...              6.8      25.0      8.3  2012      1
# 24       27     0     ...              8.2      28.0      8.7  2012      1
# 25       28     0     ...              1.7      35.0      4.2  2012      1
# 26       26     0     ...              3.2      36.0      7.5  2012      1
# 27       25     0     ...              5.5      25.0      8.0  2012      1
# 28       28     0     ...             10.4      25.0     11.4  2012      1
# 29       33     0     ...              6.6      28.0      7.7  2012      1
# ...     ...   ...     ...              ...       ...      ...   ...    ...
# 19635     0    15     ...              4.4      19.0      9.7  2014     10
# 19636     0     5     ...              8.2      34.0      9.0  2014     10
# 19637     2     0     ...              2.2      15.0      5.3  2014     10
# 19638     0     8     ...              7.3      17.0      8.0  2014     10
# 19639     0    10     ...              6.7      15.0      8.5  2014     10
# 19640     0    18     ...              5.7      17.0      8.3  2014     10
# 19641     0    17     ...              8.4      15.0      9.7  2014     10
# 19642     0    19     ...              8.8      16.0      9.4  2014     10
# 19643     0    14     ...              2.8      20.0      8.1  2014     10
# 19644     6     0     ...              9.6      31.0     10.0  2014     10
# 19645     2     0     ...              7.2      15.0      8.3  2014     10
# 19646     0     3     ...             13.0      29.0     15.3  2014     10
# 19647     0     2     ...             10.7      29.0     11.6  2014     10
# 19648     0     1     ...              0.7      19.0      3.2  2014     10
# 19649     0     9     ...              5.7      19.0      6.8  2014     10
# 19650     0     9     ...              1.8      10.0      4.6  2014     10
# 19651     0     9     ...              7.7       6.0      8.3  2014     10
# 19652     0     2     ...              6.2      11.0      6.7  2014     10
# 19653     0     5     ...              2.8      14.0      3.5  2014     10
# 19654     0     4     ...              3.4      14.0      3.7  2014     10
# 19655     0     5     ...              5.8      12.0      6.0  2014     10
# 19656     0     6     ...              4.7      14.0      6.0  2014     10
# 19657     0     7     ...              4.6      17.0      5.9  2014     10
# 19658     0    12     ...              2.5      17.0      5.0  2014     10
# 19659     0    13     ...              6.3      17.0      8.0  2014     10
# 19660     0    10     ...             10.0      18.0     10.4  2014     10
# 19661     0     9     ...              3.1      36.0      6.4  2014     10
# 19662     0     1     ...              4.9       6.0      6.1  2014     10
# 19663     0     1     ...              1.6      14.0      4.9  2014     10
# 19664     6     0     ...             10.5      36.0     11.2  2014     10
#
#        day  weekday      holiday  is_weekend   is_holiday
# 0        1        6      holiday     weekend      holiday
# 1        2        0  regular day     weekday      holiday
# 2        3        1  regular day     weekday  regular day
# 3        4        2  regular day     weekday  regular day
# 4        5        3  regular day     weekday  regular day
# 5        6        4  regular day     weekday  regular day
# 6        7        5  regular day      Friday  regular day
# 7        8        6  regular day     weekend  regular day
# 8        9        0  regular day     weekday  regular day
# 9       10        1  regular day     weekday  regular day
# 10      11        2  regular day     weekday  regular day
# 11      12        3  regular day     weekday  regular day
# 12      13        4  regular day     weekday  regular day
# 13      14        5  regular day      Friday  regular day
# 14      15        6  regular day     weekend  regular day
# 15      16        0      holiday     weekday      holiday
# 16      17        1  regular day     weekday  regular day
# 17      18        2  regular day     weekday  regular day
# 18      19        3  regular day     weekday  regular day
# 19      20        4  regular day     weekday  regular day
# 20      21        5  regular day      Friday  regular day
# 21      22        6  regular day     weekend  regular day
# 22      23        0  regular day     weekday  regular day
# 23      24        1  regular day     weekday  regular day
# 24      25        2  regular day     weekday  regular day
# 25      26        3  regular day     weekday  regular day
# 26      27        4  regular day     weekday  regular day
# 27      28        5  regular day      Friday  regular day
# 28      29        6  regular day     weekend  regular day
# 29      30        0  regular day     weekday  regular day
# ...    ...      ...          ...         ...          ...
# 19635    2        3  regular day     weekday  regular day
# 19636    3        4  regular day     weekday  regular day
# 19637    4        5  regular day      Friday  regular day
# 19638    5        6  regular day     weekend  regular day
# 19639    6        0  regular day     weekday  regular day
# 19640    7        1  regular day     weekday  regular day
# 19641    8        2  regular day     weekday  regular day
# 19642    9        3  regular day     weekday  regular day
# 19643   10        4  regular day     weekday  regular day
# 19644   11        5  regular day      Friday  regular day
# 19645   12        6  regular day     weekend  regular day
# 19646   13        0      holiday     weekday      holiday
# 19647   14        1  regular day     weekday  regular day
# 19648   15        2  regular day     weekday  regular day
# 19649   16        3  regular day     weekday  regular day
# 19650   17        4  regular day     weekday  regular day
# 19651   18        5  regular day      Friday  regular day
# 19652   19        6  regular day     weekend  regular day
# 19653   20        0  regular day     weekday  regular day
# 19654   21        1  regular day     weekday  regular day
# 19655   22        2  regular day     weekday  regular day
# 19656   23        3  regular day     weekday  regular day
# 19657   24        4  regular day     weekday  regular day
# 19658   25        5  regular day      Friday  regular day
# 19659   26        6  regular day     weekend  regular day
# 19660   27        0  regular day     weekday  regular day
# 19661   28        1  regular day     weekday  regular day
# 19662   29        2  regular day     weekday  regular day
# 19663   30        3  regular day     weekday  regular day
# 19664   31        4      holiday     weekday      holiday
#
# [19665 rows x 27 columns]

# %%
df_submission = df_submission.merge(df_weather, on=["station_nbr","date"])

# %%
df_submission
# Out:
#         units  store_nbr item_nbr        date  station_nbr  tmax  tmin  tavg  \
# 0           0          2        1  2013-04-01           14    71    42    56
# 1           0          2        2  2013-04-01           14    71    42    56
# 2           0          2        3  2013-04-01           14    71    42    56
# 3           0          2        4  2013-04-01           14    71    42    56
# 4           0          2        5  2013-04-01           14    71    42    56
# 5           0          2        6  2013-04-01           14    71    42    56
# 6           0          2        7  2013-04-01           14    71    42    56
# 7           0          2        8  2013-04-01           14    71    42    56
# 8           0          2        9  2013-04-01           14    71    42    56
# 9           0          2       10  2013-04-01           14    71    42    56
# 10          0          2       11  2013-04-01           14    71    42    56
# 11          0          2       12  2013-04-01           14    71    42    56
# 12          0          2       13  2013-04-01           14    71    42    56
# 13          0          2       14  2013-04-01           14    71    42    56
# 14          0          2       15  2013-04-01           14    71    42    56
# 15          0          2       16  2013-04-01           14    71    42    56
# 16          0          2       17  2013-04-01           14    71    42    56
# 17          0          2       18  2013-04-01           14    71    42    56
# 18          0          2       19  2013-04-01           14    71    42    56
# 19          0          2       20  2013-04-01           14    71    42    56
# 20          0          2       21  2013-04-01           14    71    42    56
# 21          0          2       22  2013-04-01           14    71    42    56
# 22          0          2       23  2013-04-01           14    71    42    56
# 23          0          2       24  2013-04-01           14    71    42    56
# 24          0          2       25  2013-04-01           14    71    42    56
# 25          0          2       26  2013-04-01           14    71    42    56
# 26          0          2       27  2013-04-01           14    71    42    56
# 27          0          2       28  2013-04-01           14    71    42    56
# 28          0          2       29  2013-04-01           14    71    42    56
# 29          0          2       30  2013-04-01           14    71    42    56
# ...       ...        ...      ...         ...          ...   ...   ...   ...
# 526887      0         40       82  2014-08-02           13    81    51    66
# 526888      0         40       83  2014-08-02           13    81    51    66
# 526889      0         40       84  2014-08-02           13    81    51    66
# 526890      0         40       85  2014-08-02           13    81    51    66
# 526891      0         40       86  2014-08-02           13    81    51    66
# 526892      0         40       87  2014-08-02           13    81    51    66
# 526893      0         40       88  2014-08-02           13    81    51    66
# 526894      0         40       89  2014-08-02           13    81    51    66
# 526895      0         40       90  2014-08-02           13    81    51    66
# 526896      0         40       91  2014-08-02           13    81    51    66
# 526897      0         40       92  2014-08-02           13    81    51    66
# 526898      0         40       93  2014-08-02           13    81    51    66
# 526899      0         40       94  2014-08-02           13    81    51    66
# 526900      0         40       95  2014-08-02           13    81    51    66
# 526901      0         40       96  2014-08-02           13    81    51    66
# 526902      0         40       97  2014-08-02           13    81    51    66
# 526903      0         40       98  2014-08-02           13    81    51    66
# 526904      0         40       99  2014-08-02           13    81    51    66
# 526905      0         40      100  2014-08-02           13    81    51    66
# 526906      0         40      101  2014-08-02           13    81    51    66
# 526907      0         40      102  2014-08-02           13    81    51    66
# 526908      0         40      103  2014-08-02           13    81    51    66
# 526909      0         40      104  2014-08-02           13    81    51    66
# 526910      0         40      105  2014-08-02           13    81    51    66
# 526911      0         40      106  2014-08-02           13    81    51    66
# 526912      0         40      107  2014-08-02           13    81    51    66
# 526913      0         40      108  2014-08-02           13    81    51    66
# 526914      0         40      109  2014-08-02           13    81    51    66
# 526915      0         40      110  2014-08-02           13    81    51    66
# 526916      0         40      111  2014-08-02           13    81    51    66
#
#         depart  dewpoint     ...       resultspeed  resultdir  avgspeed  year  \
# 0            1        41     ...               9.3        4.0      11.0  2013
# 1            1        41     ...               9.3        4.0      11.0  2013
# 2            1        41     ...               9.3        4.0      11.0  2013
# 3            1        41     ...               9.3        4.0      11.0  2013
# 4            1        41     ...               9.3        4.0      11.0  2013
# 5            1        41     ...               9.3        4.0      11.0  2013
# 6            1        41     ...               9.3        4.0      11.0  2013
# 7            1        41     ...               9.3        4.0      11.0  2013
# 8            1        41     ...               9.3        4.0      11.0  2013
# 9            1        41     ...               9.3        4.0      11.0  2013
# 10           1        41     ...               9.3        4.0      11.0  2013
# 11           1        41     ...               9.3        4.0      11.0  2013
# 12           1        41     ...               9.3        4.0      11.0  2013
# 13           1        41     ...               9.3        4.0      11.0  2013
# 14           1        41     ...               9.3        4.0      11.0  2013
# 15           1        41     ...               9.3        4.0      11.0  2013
# 16           1        41     ...               9.3        4.0      11.0  2013
# 17           1        41     ...               9.3        4.0      11.0  2013
# 18           1        41     ...               9.3        4.0      11.0  2013
# 19           1        41     ...               9.3        4.0      11.0  2013
# 20           1        41     ...               9.3        4.0      11.0  2013
# 21           1        41     ...               9.3        4.0      11.0  2013
# 22           1        41     ...               9.3        4.0      11.0  2013
# 23           1        41     ...               9.3        4.0      11.0  2013
# 24           1        41     ...               9.3        4.0      11.0  2013
# 25           1        41     ...               9.3        4.0      11.0  2013
# 26           1        41     ...               9.3        4.0      11.0  2013
# 27           1        41     ...               9.3        4.0      11.0  2013
# 28           1        41     ...               9.3        4.0      11.0  2013
# 29           1        41     ...               9.3        4.0      11.0  2013
# ...        ...       ...     ...               ...        ...       ...   ...
# 526887      -5        47     ...               5.7       17.0       6.5  2014
# 526888      -5        47     ...               5.7       17.0       6.5  2014
# 526889      -5        47     ...               5.7       17.0       6.5  2014
# 526890      -5        47     ...               5.7       17.0       6.5  2014
# 526891      -5        47     ...               5.7       17.0       6.5  2014
# 526892      -5        47     ...               5.7       17.0       6.5  2014
# 526893      -5        47     ...               5.7       17.0       6.5  2014
# 526894      -5        47     ...               5.7       17.0       6.5  2014
# 526895      -5        47     ...               5.7       17.0       6.5  2014
# 526896      -5        47     ...               5.7       17.0       6.5  2014
# 526897      -5        47     ...               5.7       17.0       6.5  2014
# 526898      -5        47     ...               5.7       17.0       6.5  2014
# 526899      -5        47     ...               5.7       17.0       6.5  2014
# 526900      -5        47     ...               5.7       17.0       6.5  2014
# 526901      -5        47     ...               5.7       17.0       6.5  2014
# 526902      -5        47     ...               5.7       17.0       6.5  2014
# 526903      -5        47     ...               5.7       17.0       6.5  2014
# 526904      -5        47     ...               5.7       17.0       6.5  2014
# 526905      -5        47     ...               5.7       17.0       6.5  2014
# 526906      -5        47     ...               5.7       17.0       6.5  2014
# 526907      -5        47     ...               5.7       17.0       6.5  2014
# 526908      -5        47     ...               5.7       17.0       6.5  2014
# 526909      -5        47     ...               5.7       17.0       6.5  2014
# 526910      -5        47     ...               5.7       17.0       6.5  2014
# 526911      -5        47     ...               5.7       17.0       6.5  2014
# 526912      -5        47     ...               5.7       17.0       6.5  2014
# 526913      -5        47     ...               5.7       17.0       6.5  2014
# 526914      -5        47     ...               5.7       17.0       6.5  2014
# 526915      -5        47     ...               5.7       17.0       6.5  2014
# 526916      -5        47     ...               5.7       17.0       6.5  2014
#
#        month day  weekday      holiday  is_weekend   is_holiday
# 0          4   1        0  regular day     weekday  regular day
# 1          4   1        0  regular day     weekday  regular day
# 2          4   1        0  regular day     weekday  regular day
# 3          4   1        0  regular day     weekday  regular day
# 4          4   1        0  regular day     weekday  regular day
# 5          4   1        0  regular day     weekday  regular day
# 6          4   1        0  regular day     weekday  regular day
# 7          4   1        0  regular day     weekday  regular day
# 8          4   1        0  regular day     weekday  regular day
# 9          4   1        0  regular day     weekday  regular day
# 10         4   1        0  regular day     weekday  regular day
# 11         4   1        0  regular day     weekday  regular day
# 12         4   1        0  regular day     weekday  regular day
# 13         4   1        0  regular day     weekday  regular day
# 14         4   1        0  regular day     weekday  regular day
# 15         4   1        0  regular day     weekday  regular day
# 16         4   1        0  regular day     weekday  regular day
# 17         4   1        0  regular day     weekday  regular day
# 18         4   1        0  regular day     weekday  regular day
# 19         4   1        0  regular day     weekday  regular day
# 20         4   1        0  regular day     weekday  regular day
# 21         4   1        0  regular day     weekday  regular day
# 22         4   1        0  regular day     weekday  regular day
# 23         4   1        0  regular day     weekday  regular day
# 24         4   1        0  regular day     weekday  regular day
# 25         4   1        0  regular day     weekday  regular day
# 26         4   1        0  regular day     weekday  regular day
# 27         4   1        0  regular day     weekday  regular day
# 28         4   1        0  regular day     weekday  regular day
# 29         4   1        0  regular day     weekday  regular day
# ...      ...  ..      ...          ...         ...          ...
# 526887     8   2        5  regular day      Friday  regular day
# 526888     8   2        5  regular day      Friday  regular day
# 526889     8   2        5  regular day      Friday  regular day
# 526890     8   2        5  regular day      Friday  regular day
# 526891     8   2        5  regular day      Friday  regular day
# 526892     8   2        5  regular day      Friday  regular day
# 526893     8   2        5  regular day      Friday  regular day
# 526894     8   2        5  regular day      Friday  regular day
# 526895     8   2        5  regular day      Friday  regular day
# 526896     8   2        5  regular day      Friday  regular day
# 526897     8   2        5  regular day      Friday  regular day
# 526898     8   2        5  regular day      Friday  regular day
# 526899     8   2        5  regular day      Friday  regular day
# 526900     8   2        5  regular day      Friday  regular day
# 526901     8   2        5  regular day      Friday  regular day
# 526902     8   2        5  regular day      Friday  regular day
# 526903     8   2        5  regular day      Friday  regular day
# 526904     8   2        5  regular day      Friday  regular day
# 526905     8   2        5  regular day      Friday  regular day
# 526906     8   2        5  regular day      Friday  regular day
# 526907     8   2        5  regular day      Friday  regular day
# 526908     8   2        5  regular day      Friday  regular day
# 526909     8   2        5  regular day      Friday  regular day
# 526910     8   2        5  regular day      Friday  regular day
# 526911     8   2        5  regular day      Friday  regular day
# 526912     8   2        5  regular day      Friday  regular day
# 526913     8   2        5  regular day      Friday  regular day
# 526914     8   2        5  regular day      Friday  regular day
# 526915     8   2        5  regular day      Friday  regular day
# 526916     8   2        5  regular day      Friday  regular day
#
# [526917 rows x 30 columns]
